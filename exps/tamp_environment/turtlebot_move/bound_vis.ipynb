# %%
from nonasymptotic.bound import compute_numerical_bound
import random
import matplotlib.pyplot as plt

compute_numerical_bound(0.05, 0.9, 8, 2, None)
# Out:
# (112174, 0.1)

# %%
plt.figure()
deltas = []
off = 0.00
for _ in range(100):
    deltas.append(random.uniform(0.04+off, 0.15+off))
bounds = [compute_numerical_bound(delta, 0.9, 3, 2, None)[0] for delta in deltas]

plt.scatter(deltas, bounds)

deltas = []
off = 0.05
for _ in range(100):
    deltas.append(random.uniform(0.04+off, 0.15+off))
bounds = [compute_numerical_bound(delta, 1e-3, 16, 2, None)[0] for delta in deltas]

plt.scatter(deltas, bounds)
